# %%
#mode
#r >> read mode
#w>> write mode
#a >> append mode
#r+>> both reading and writing

# %%
open("files.txt", 'r') #if there is no any file, and you open it in read mode it will throw an error
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 open("files.txt", 'r') #if there is no any file, and you open it in read mode it will throw an error
#
# File c:\Users\rames\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'files.txt'

# %%
file = open("file.txt", "w") #w>>write mode, if a file is not there it will create the file.txt and then read it

# %%
file.write("Hello this is my first line in the text file") #number below is no of bytes you have written
# Out:
# 44

# %%
#as of now if you open the written file you will not be able to see any text in file
#to see you have to close the file

# %%
file.close()

# %%
file #file attributes
# Out:
# <_io.TextIOWrapper name='file.txt' mode='w' encoding='cp65001'>

# %%
file.closed #if file is closed it will return true else false
# Out:
# True

# %%
file = open("file.txt", "r")

# %%
file.closed
# Out:
# False

# %%
file.close()

# %%
file.closed
# Out:
# True

# %%
file.name
# Out:
# 'file.txt'

# %%
file.mode
# Out:
# 'r'

# %%
file.closed
# Out:
# True

# %%
file.write("This is my second line") #this will not be executed, throw an error>> file is closed>>you can not write anything in closed file
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 file.write("This is my second line") #this will not be executed, throw an error>> file is closed>>you can not write anything in closed file
#
# ValueError: I/O operation on closed file.

# %%
file = open("file.txt", "w") #it will truncate(delete) all earlier contetnt and make a fresh file.txt

# %%
file.close()

# %%
file = open("file.txt", "w")
file.write("This is my first line\n")
file.write("This is my second line\n")
file.write("This is my third line\n")
file.write("This is my fourth line\n")
file.close()

# %%
file = open("file.txt", "w")
file.write("This is fifth line") #all earlier content will deleted
file.close() # overrite

# %%
file = open("file.txt", "w")
file.write("This is my first line\n")
file.write("This is my second line\n")
file.write("This is my third line\n")
file.write("This is my fourth line\n")
file.close()

# %%
file = open("file.txt", "a") #append the new line
file.write("This is fifth line")
file.close()

# %%
file = open("file.txt", 'r')

# %%
file.write("this is another line")
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 file.write("this is another line")
#
# UnsupportedOperation: not writable

# %%
file
# Out:
# <_io.TextIOWrapper name='file.txt' mode='r' encoding='cp65001'>

# %%
#various way of printing lines
for i in file:
    print(i)
# Out:
# This is my first line
#
# This is my second line
#
# This is my third line
#
# This is my fourth line
#
# This is fifth lineThis is fifth line

# %%
print(file.read()) #here the cursor/pointer is at last position
# Out:
# This is my first line
# This is my second line
# This is my third line
# This is my fourth line
# This is fifth lineThis is fifth line

# %%
file.read()
# Out:
# ''

# %%
file.tell() #it tellse the current position of the cursor
# Out:
# 130

# %%
file.seek(0)
# Out:
# 0

# %%
f = open("file.txt", 'r')
f.seek(0) #it will bring cursor to start of the the file
print(f.read()) #it will read everything from starting
f.close()
# Out:
# This is my first line
# This is my second line
# This is my third line
# This is my fourth line
# This is fifth lineThis is fifth line

# %%
f = open("file.txt", 'r')
print(f.readline()) #it will only read the first line
f.close()
# Out:
# This is my first line

# %%
f = open("file.txt", 'r')
print(f.readlines())  #all the lines will be the element of a list
f.close()
# Out:
# ['This is my first line\n', 'This is my second line\n', 'This is my third line\n', 'This is my fourth line\n', 'This is fifth lineThis is fifth line']

# %%
#present working directory
# !pwd
# Out:
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import os

# %%
os.getcwd()
# Out:
# 'r:\\data  analytics  pw\\python pw\\m6.File, exceptional handling & mm'

# %%
ls
# Out:
#  Volume in drive R is Ramesh
#  Volume Serial Number is AEB0-B1ED
#
#  Directory of r:\data  analytics  pw\python pw\m6.File, exceptional handling & mm
#
# 06.02.26  19:25    <DIR>          .
# 07.09.25  21:55    <DIR>          ..
# 06.02.26  19:29            26,034 1. files_handling_basics.ipynb
# 07.09.25  21:54            19,475 1. logging_debugging.ipynb
# 07.09.25  21:54             7,391 2. file_reading_writing.ipynb
# 07.09.25  21:54            14,818 2.multithreading.ipynb
# 07.09.25  21:54         2,910,885 Best Practice Exception Handling.pdf
# 07.09.25  21:54         6,293,046 Custom Exception Handling.pdf
# 07.09.25  21:54         5,155,131 Exception Handling Using Try Catch Block.pdf
# 07.09.25  21:54            20,587 exceptions handling.ipynb
# 06.02.26  19:28               130 file.txt
# 07.09.25  21:54            29,836 General use of exceptions and best practices.ipynb
# 07.09.25  21:54         2,123,620 List Of General Use Exception (1).pdf
# 07.09.25  21:54            10,785 multiprocessing.ipynb
# 07.09.25  21:54        12,211,711 Multiprocessing.pdf
# 07.09.25  21:54        11,454,820 Multithreading.pdf
#               14 File(s)     40,278,269 bytes
#                2 Dir(s)  54,640,852,992 bytes free

# %%
os.path.getsize("file.txt")
# Out:
# 130

# %%
os.mkdir("test")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 os.mkdir("test")
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'test'

# %%
os.mkdir("test/test1")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 os.mkdir("test/test1")
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'test/test1'

# %%
os.mkdir("1/2") #it will throw an error>>because 1 is not made first
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 os.mkdir("1/2")
#
# FileNotFoundError: [Errno 2] No such file or directory: '1/2'

# %%
os.makedirs("1/2/3/4")

# %%
ls
# Out:
#  Volume in drive R is Ramesh
#  Volume Serial Number is AEB0-B1ED
#
#  Directory of r:\data  analytics  pw\python pw\m6.File, exceptional handling & mm
#
# 06.02.26  19:31    <DIR>          .
# 07.09.25  21:55    <DIR>          ..
# 06.02.26  19:38            29,368 1. files_handling_basics.ipynb
# 07.09.25  21:54            19,475 1. logging_debugging.ipynb
# 07.09.25  21:54             7,391 2. file_reading_writing.ipynb
# 07.09.25  21:54            14,818 2.multithreading.ipynb
# 07.09.25  21:54         2,910,885 Best Practice Exception Handling.pdf
# 07.09.25  21:54         6,293,046 Custom Exception Handling.pdf
# 07.09.25  21:54         5,155,131 Exception Handling Using Try Catch Block.pdf
# 07.09.25  21:54            20,587 exceptions handling.ipynb
# 06.02.26  19:28               130 file.txt
# 07.09.25  21:54            29,836 General use of exceptions and best practices.ipynb
# 07.09.25  21:54         2,123,620 List Of General Use Exception (1).pdf
# 07.09.25  21:54            10,785 multiprocessing.ipynb
# 07.09.25  21:54        12,211,711 Multiprocessing.pdf
# 07.09.25  21:54        11,454,820 Multithreading.pdf
# 06.02.26  19:31    <DIR>          test
#               14 File(s)     40,281,603 bytes
#                3 Dir(s)  54,640,848,896 bytes free

# %%
os.listdir()
# Out:
# ['1. files_handling_basics.ipynb',
#  '1. logging_debugging.ipynb',
#  '2. file_reading_writing.ipynb',
#  '2.multithreading.ipynb',
#  'Best Practice Exception Handling.pdf',
#  'Custom Exception Handling.pdf',
#  'Exception Handling Using Try Catch Block.pdf',
#  'exceptions handling.ipynb',
#  'file.txt',
#  'General use of exceptions and best practices.ipynb',
#  'List Of General Use Exception (1).pdf',
#  'multiprocessing.ipynb',
#  'Multiprocessing.pdf',
#  'Multithreading.pdf',
#  'test']

# %%
os.mkdir("feat")

# %%
os.rmdir("feat") #to delete one directory without any content inside the directory

# %%
os.rmdir("test") #throw an error as test is not empty
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 os.rmdir("test") #throw an error as test is not empty
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'test'

# %%
import shutil
shutil.rmtree("test") #it will remove the folder hierarchy

# %%
os.getcwd()
# Out:
# 'r:\\data  analytics  pw\\python pw\\m6.File, exceptional handling & mm'

# %%
os.makedirs("test/test1")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 os.makedirs("test/test1")
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'test/test1'

# %%
f = open("r:\\data  analytics  pw\\python pw\\m6.File, exceptional handling & mm/test/test1/file.txt", "w")

# %%
#copying the above file in the current location >> /home/jovyan/work
#shutil.copy(src, dest)

# %%
shutil.copy() #keep a copy at original source as well
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 shutil.copy("/home/jovyan/work/test/test1/file.txt", '/home/jovyan/work') #keep a copy at original source as well
#
# File c:\Users\rames\AppData\Local\Programs\Python\Python311\Lib\shutil.py:431, in copy(src, dst, follow_symlinks)
#     429 if os.path.isdir(dst):
#     430     dst = os.path.join(dst, os.path.basename(src))
# --> 431 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     432 copymode(src, dst, follow_symlinks=follow_symlinks)
#     433 return dst
#
# File c:\Users\rames\AppData\Local\Programs\Python\Python311\Lib\shutil.py:256, in copyfile(src, dst, follow_symlinks)
#     254     os.symlink(os.readlink(src), dst)
#     255 else:
# --> 256     with open(src, 'rb') as fsrc:
#     257         try:
#     258             with open(dst, 'wb') as fdst:
#     259                 # macOS
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jovyan/work/test/test1/file.txt'

# %%
#move a file

# %%
os.mkdir("file_test")

# %%
shutil.move("/home/jovyan/work/test/test1/file.txt", '/home/jovyan/work/file_test')
# Out:
# '/home/jovyan/work/file_test/file.txt'

# %%
#move will remove the file from original source to destination source

# %%
with open('file.txt', 'w') as f:
    f.write("This is my first line")

# %%
#with statment ensures that the file is closed properly after the block of code is executed
#important>> free up system resources and avoid issues like data corruption or file lock

# %%
with open("file.txt", 'r') as f:
    line = f.readline()
    print(line)
# Out:
# This is my first line
