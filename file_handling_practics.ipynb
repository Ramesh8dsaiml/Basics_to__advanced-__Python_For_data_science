# %%
f = open("data.txt", "r") #it will throw an errors becouse it have no any filees
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 f = open("data.txt", "r") #it will throw an errors becouse it have no any filees
#
# File d:\My_python\MY_jupyter_invionments\myenv\Lib\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data.txt'

# %%
f = open("data.txt", "w")
f.write("hii khushi kaise ho aaj kal ")
f.close()

# %%
f = open("data.txt", "r")

# %%
data = f.read()
print(data )
f.close()
# Out:
# hii khushi kaise ho aaj kal

# %%
f = open("data.txt")
print(f.readline())
f.close()
# Out:
# hii khushi kaise ho aaj kal

# %%
f = open("data.txt")
print(f.readlines())
f.close()
# Out:
# ['hii khushi kaise ho aaj kal ']

# %%
f= open("data.txt","w") # overload 
f.write("my name is ramesh kumar i from haryana ok ")
f.close()

# %%
f= open("data.txt","r")

data =f.read()
print(data)
f.close()
# Out:
# my name is ramesh kumar i from haryana ok

# %%
f= open("data.txt","w+") # overload 
f.write("my name is ramesh kumar i from haryana ok ,and my friend blongs to panjab ")

f= open("data.txt","r")

data =f.read()
print(data)
f.close()
# Out:
# my name is ramesh kumar i from haryana ok ,and my friend blongs to panjab

# %%
f= open("data.txt","r")

data =f.read()
print(data)
f.close()
# Out:
# my name is ramesh kumar i from haryana ok ,and my friend blongs to panjab

# %%
l=open("data.docx","x")
l.write("hii my name is ramesh  kumar  , i from haryana ")
l.close()
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 l=open("data.docx","x")
#       2 l.write("hii my name is ramesh  kumar  , i from haryana ")
#       3 l.close()
#
# File d:\My_python\MY_jupyter_invionments\myenv\Lib\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileExistsError: [Errno 17] File exists: 'data.docx'

# %%
l=open("data.docx", "a")
l.write("\nhii khushi")
l.close()

# %%
l=open("data.docx","r")
data=l.read()
print(data)
l.close()
# Out:
# hii my name is ramesh  kumar
# hii khushi
# hii khushi
# hii khushi

# %%
l=open("data.docx","r")
data=l.read()
print(data)
l.close()
# Out:
# hii my name is ramesh  kumar
# hii khushi
# hii khushi
# hii khushi
