# %% [markdown]
# # Exception:
# - Exception handling allows a program to handle runtime errors gracefully without crashing.In many programming languages, you can use try-catch blocks to catch exceptions and handle them appropriately. Here's an example in Python:

# %%
print(10 / 0)   # program crash
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(10 / 0)   # program crash
#
# ZeroDivisionError: division by zero

# %%
try:
    print(10 / 0)
except:
    print("Error aa gaya, par program crash nahi hua")
# Out:
# Error aa gaya, par program crash nahi hua

# %%
# try:
#     risky_code
# except:
#     handling_code
try:
    x = int("abc")
except:
    print("wrong values ")
# Out:
# wrong values

# %%
try:
    a = int(input("Enter number: "))
    print(10 / a)
except:
    print("Error aaya")
# Out:
# 1.0

# %%
try:
    a = int(input("Enter number: "))
    print(10 / a)
except:
    print("name") # enter name
# Out:
# name

# %%
# try with finally:

# try:
#     risky_code
# except:
#     error_handling
# finally:
#     cleanup_code
try:
    f = open("data.txt", "r")
    print(f.read())
except:
    print("File error")
finally:
    print("File close / cleanup ka kaam")
# Out:
# my name is ramesh kumar i from haryana ok ,and my friend blongs to panjab
# File close / cleanup ka kaam

# %% [markdown]
# ![{686BAC66-99E5-4008-A41A-7859DD7BF4B7}.png](attachment:{686BAC66-99E5-4008-A41A-7859DD7BF4B7}.png)
#
# - Exception Handling is a mechanism in Python used to handle runtime errors so that the normal flow of the program is not interrupted.
#
# - 🔸 try block
#
# - The try block contains code that may cause an error.
#
# - 🔸 except block
#
# - The except block handles the error if it occurs.
#
# - 🔸 finally block
#
# - The finally block always executes whether an exception occurs or not.

# %%
help(Exception)
# Out:
# Help on class Exception in module builtins:
#
# class Exception(BaseException)
#  |  Common base class for all non-exit exceptions.
#  |
#  |  Method resolution order:
#  |      Exception
#  |      BaseException
#  |      object
#  |
#  |  Built-in subclasses:
#  |      ArithmeticError
#  |      AssertionError
#  |      AttributeError
#  |      BufferError
#  |      ... and 16 other subclasses
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs)
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from BaseException:
#  |
#  |  __delattr__(self, name, /)
#  |      Implement delattr(self, name).
#  |
# ...

# %%
help(ValueError)
# Out:
# Help on class ValueError in module builtins:
#
# class ValueError(Exception)
#  |  Inappropriate argument value (of correct type).
#  |
#  |  Method resolution order:
#  |      ValueError
#  |      Exception
#  |      BaseException
#  |      object
#  |
#  |  Built-in subclasses:
#  |      UnicodeError
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs)
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from BaseException:
#  |
#  |  __delattr__(self, name, /)
#  |      Implement delattr(self, name).
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
# ...

# %%
ArithmeticError.__subclasses__()
# Out:
# [FloatingPointError,
#  OverflowError,
#  ZeroDivisionError,
#  decimal.DecimalException]

# %%
LookupError.__subclasses__()
# Out:
# [IndexError, KeyError, encodings.CodecRegistryError]

# %%
import builtins
builtins.Exception.__subclasses__()
# Out:
# [ArithmeticError,
#  AssertionError,
#  AttributeError,
#  BufferError,
#  EOFError,
#  ImportError,
#  LookupError,
#  MemoryError,
#  NameError,
#  OSError,
#  ReferenceError,
#  RuntimeError,
#  StopAsyncIteration,
#  StopIteration,
#  SyntaxError,
#  SystemError,
#  TypeError,
#  ValueError,
#  Warning,
#  ExceptionGroup,
#  warnings._OptionError,
#  runpy._Error,
#  re.error,
#  locale.Error,
#  subprocess.SubprocessError,
#  zmq.error.ZMQBaseError,
#  struct.error,
#  _pickle.PickleError,
#  pickle._Stop,
#  tokenize.TokenError,
#  tokenize.StopTokenizing,
#  concurrent.futures._base.Error,
#  socket._GiveupOnSendfile,
#  binascii.Incomplete,
#  inspect.ClassFoundException,
#  inspect.EndOfBlock,
#  asyncio.exceptions.InvalidStateError,
#  asyncio.exceptions.LimitOverrunError,
#  asyncio.queues.QueueEmpty,
#  asyncio.queues.QueueFull,
#  zlib.error,
#  _lzma.LZMAError,
#  shutil.RegistryError,
#  shutil._GiveupOnFastCopy,
#  traitlets.traitlets.TraitError,
#  copy.Error,
# ...

# %%
#  Exception: This is the base class for all built-in exceptions. It catches all exceptions that inherit from it
def process_data(data):
    try:
        return data["value"]
    except Exception as e:
        print("Something went wrong:", e)

# %% [markdown]
# some genral exception types errors :
# 1. -ArithmeticError: Raised when an error occurs in arithmetic operations.
#   - example: division by zero, overflow, etc.
#   - arihmeticerrors include ZeroDivisionError, OverflowError, FloatingPointError
#   - x = 10 / 0
# 2. lockerror: when index or key is not found in a sequence or mapping.
#   - example: list index out of range, key error, etc.
#   - lookuperror include IndexError, KeyError
#   - my_list = [1, 2, 3]
#   - print(my_list[5])
#
# 3. AssertionError: when condition is failds , assert statement is used to check if a condition is true. If the condition is false, an AssertionError is raised.
#   example: assert x > 0, "x must be positive"
#   x = -5
#   assert x > 0, "x must be positive"
#
# 4. atributeerror:  attribute mising  or not found
#    - example :
#    - my_string = "Hello"
#    - print(my_string.uppercase()) # AttributeError: 'str' object has no attribute 'uppercase'
#
# 5. EOFError: input end unexpected
# 6. importerrroe: import is failds
# 7. modulenotfounderror: modules is note found
# 8. oserror: os/files system error
# 9. typeerror: wrong data type
# 10. valueerror: wrong value
# 11. nameerror: variable is not defined
# 12. notimplemetederror: method is not implemented
# 13. keyerror: dictinary key is mising
# etc

# %%
try:
    x = 10 / 0
except ZeroDivisionError:
    print("Division by zero not allowed")
# Out:
# Division by zero not allowed

# %%
try:
    data = int("abc")
except ValueError:
    print("Invalid conversion")
except TypeError:
    print("Wrong type")
# Out:
# Invalid conversion

# %%
try:
    f = open("mydata.txt")
    print(f.read())
except FileNotFoundError:
    print("File missing")
finally:
    print("Cleanup done")
# Out:
# File missing
# Cleanup done

# %%
#best practice
#in case you know specific exception keep that block first 
#and the block of generic exception after that

try:
    f = open("sample.txt", "r")
    f.read()
except FileNotFoundError as e:
    print("The following file was not created, please re run the code", e)
except Exception as e: #parent class
    print("first msg-----File is not opened due to", e)

# %%
#anothe rexample of above case
try:
    10/"string"
except ZeroDivisionError as e:
    print("The divison is not possible due the error>>", e)
except Exception as e:
    print("The error is", e)
# Out:
# The error is unsupported operand type(s) for /: 'int' and 'str'

# %%
#best practice>> always try to log
import logging
logging.basicConfig(filename = "program.log", level = logging.DEBUG)
try:
    f = open("example.txt", "r")
    f.read()
except FileNotFoundError as e:
    logging.error(f"My file was not found  yes {e}")

# %%
import logging
logging.basicConfig(filename = "program1.log", level = logging.DEBUG)
try:
    10/0
except ZeroDivisionError as e:
    logging.error(f"My file was not found {e}")

# %%
#best practice>> always try to log
import logging
logging.basicConfig(filename = "program.log", level = logging.DEBUG)
try:
    f = open("example.txt", "r")
    f.read()
except FileNotFoundError as e:
    logging.error(f"My file was not found somthing else : {e}")

# %%
import logging

logging.basicConfig(level=logging.DEBUG)

logging.debug("Debugging")
logging.info("Program running")
logging.warning("Low memory")
logging.error("Something broke")
logging.critical("System crash")

# %%
import logging

logging.basicConfig(level=logging.INFO)

def train_model(data):
    if data is None:
        logging.error("Data is missing")
        return
    logging.info("Model training started")

train_model(None)
train_model([1,2,3])

# %%
import logging

logging.basicConfig(
    filename="program.log",
    level=logging.ERROR,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

logging.error("File not found")

# %%
class DataValidationError(Exception):
    """Raised when data validation fails"""
    pass

# %%
#putting exception handling in a function
def test(file):
    try:
        f = open(file, "r")
        f.read()
    except FileNotFoundError as e:
        print(f"My file was not found {e}")

# %%
#do not try to use unnecessary exception/multiple exception
#exmple:: filenotfound exception is never possible in divison
#so no point to handle filenotfound error here
#instead you can handle typeError or use generic excepction class
try:
    10/0
except ZeroDivisionError as e:
    print("The divison is not possible due the error>>", e)
except FileNotFoundError as e:
    print("The error is", e)
# Out:
# The divison is not possible due the error>> division by zero

# %%
#zero divion error doesnt make any sense here
def test(file):
    try:
        f = open(file, "r")
        f.read()
    except FileNotFoundError as e:
        print(f"My file was not found {e}")
    except ZeroDivisionError as e:#unnecesary
        print("The divison is not possible due the error>>", e)

# %%
#best practice:: give proper documentation in docstring/proper comments in your code
def test(file):
    """
    This function is about is reading a file.
    
    Args:
        input: file(str)
        output: text(str)
    """
    try:
        f = open(file, "r")
        f.read()
    except FileNotFoundError as e:
        print(f"My file was not found {e}")
    #unnecesary exception
    except ZeroDivisionError as e:
        print("The divison is not possible due the error>>", e)

# %%
#best practice>> always clean up the resources using finally


def test(file):
    """
    This function is about is reading a file.
    
    Args:
        input: file(str)
        output: text(str)
    """
    try:
        f = open(file, "w")
        f.write("Anything being written")
    except FileNotFoundError as e:
        print(f"My file was not found {e}")
    finally:
        f.close()

# %%
# Custom Exception class
class ATMWithdrawalException(Exception):
    def __init__(self, balance, amount):
        self.balance = balance
        self.amount = amount
        super().__init__(
            f"Insufficient funds. Cannot withdraw ${amount}. "
            f"Balance available: ${balance}"
        )

# Function to withdraw money
def withdraw_money(balance, amount):
    try:
        if amount > balance:
            raise ATMWithdrawalException(balance, amount)
        else:
            print(f"Withdrawal successful! Remaining balance: ${balance - amount}")
    except ATMWithdrawalException as e:
        print(e)

# Example usage
balance = 500
withdraw_amount = 700

withdraw_money(balance, withdraw_amount)
# Out:
# Insufficient funds. Cannot withdraw $700. Balance available: $500

# %%
# Custom Exception class
class StudentGradeException(Exception):
    def __init__(self, grade):
        self.grade = grade
        super().__init__(
            f"Invalid grade. Grade '{grade}' is out of range (0-100)"
        )

# Function to evaluate grade
def evaluate_grade(grade):
    try:
        if not 0 <= grade <= 100:
            raise StudentGradeException(grade)
        else:
            print("Grade evaluation successful!")
    except StudentGradeException as e:
        print(e)

# Example usage
student_grade = 120
evaluate_grade(student_grade)
# Out:
# Invalid grade. Grade '120' is out of range (0-100)

# %%
# Custom Exception for Email Sending
class EmailSendingException(Exception):
    def __init__(self, email, message):
        self.email = email
        self.message = message
        super().__init__(f"Failed to send email to '{email}': {message}")


def send_email(email, message):
    try:
        # Simulating email sending failure
        raise EmailSendingException(email, message)
    except EmailSendingException as e:
        print(e)


# Example usage
recipient_email = "example@email.com"
email_message = "This is a test message."

send_email(recipient_email, email_message)
# Out:
# Failed to send email to 'example@email.com': This is a test message.

# %%
# Custom Exception for Payment Processing
class PaymentProcessingException(Exception):
    def __init__(self, payment_method, amount):
        self.payment_method = payment_method
        self.amount = amount
        super().__init__(
            f"Payment processing failed using '{payment_method}' for amount ${amount}"
        )


def process_payment(payment_method, amount):
    try:
        # Simulating payment failure
        raise PaymentProcessingException(payment_method, amount)
    except PaymentProcessingException as e:
        print(e)


# Example usage
payment_type = "Credit Card"
payment_amount = 1000

process_payment(payment_type, payment_amount)
# Out:
# Payment processing failed using 'Credit Card' for amount $1000

# %%
# Custom Exception for Network Connection
class NetworkConnectionException(Exception):
    def __init__(self, url):
        self.url = url
        super().__init__(f"Failed to establish a connection to '{url}'")


def establish_connection(url):
    try:
        # Simulating network connection failure
        raise NetworkConnectionException(url)
    except NetworkConnectionException as e:
        print(e)


# Example usage
website_url = "https://www.linkedin.com/in/ramesh-kumar2026/"
establish_connection(website_url)
# Out:
# Failed to establish a connection to 'https://www.linkedin.com/in/ramesh-kumar2026/'
