# %% [markdown]
# # File I/O in Python
# - Python can be used to perform operations on a file. (read & write data)
# - Types of all files
# 1. Text Files : .txt, .docx, .log etc.
# 2. Binary Files : .mp4, .mov, .png, .jpeg etc.
#
# ![{99EFD54E-EC05-4622-8224-B0FCC5E84BB1}.png](attachment:{99EFD54E-EC05-4622-8224-B0FCC5E84BB1}.png)

# %%
# /1: Reading a file
# data = f.read( )  #reads entire file
# data = f.readline( ) #reads one line at a time

f= open("demo.txt","r")
data = f.read()
print(data)
print(type(data))
# Out:
# khushire very interstenig they are very interstenig , and i love it
#  and i love it
#  you are so perty girl
# <class 'str'>

# %%
f.close()

# %%
f= open("demo.txt","r")
data = f.read(5)
print(data)
print(type(data))
# line1=f.readline()
# print(line1)
f.close()
# Out:
# khush
# <class 'str'>

# %%
f = open("demo.txt","r")
data = f.read()
print(data)
print(type(data))
line1= f.readline()
print(line1)
f.close()
# Out:
#  i am learning data science  from pw skills
#  i fomr harayana
# hello brother
#
# <class 'str'>

# %%
f = open ("demo.txt", "r")
line1 = f.readline(5)
print(line1)
# Out:
#  i am

# %%
f = open ("demo.txt", "r")
data = f.read()
print(data)

line1 = f.readline()
print(line1)
line2 = f.readline()
print(line2)
f.close()
# Out:
#  i am learning data science  from pw skills
#  i fomr harayana
# hello brother

# %%
# # Writing to a file
# f = open( “demo.txt”, “w”)
# f.write( “this is a new line“ ) #overwrites the entire file

# f = open( “demo.txt”, “a”)  
# f.write( “this is a new line“ ) #adds to the fil

# %%
f =open("demo.txt","a")
f.write("\n you are so perty girl  ")
f.close()

# %%
f= open("sample.txt", "w")
f.write(" hey           are you very perty girl,")
f.close()

# %%
f= open("sample.txt","r+") # over write 
# f.write("khushi kayshap")   
print(f.read())
f.close()
# Out:
#  are you very perty girl,

# %%
f= open("sample.txt","+a") # over write 
# f.write("khushi kayshap")   
print(f.read())
f.close()

# %%
#  with Syntax
# with ope n( “demo.txt”, “a”) as f:
# data = f.read( ) 

with open("example.txt", "r") as f:
     data = f.read()
     print(data)
with open("example.txt","w") as f:
     f.write("my name is rmaesh kumar")
# Out:
# my name is rmaesh kumar

# %%
# Deleting a File
# using the os module
# Module (like a code library) is a file written by another programmer that generally has
# a functions we can use.


# import os 
# os.remove( filename )

# %%
import os 
os.remove("sys.txt")

# %% [markdown]
# # 1.qns: Create a new file “practice.txt” using python. Add the following data in it:
# - Hi everyone
# - we are learning File I/O
# - using Java.
# - I like programming in Java.
# - Apna C

# %%
with open("practics.txt","w") as f:
     f.write("hii everyone\n we are learning file I/O\n")
     f.write("using  java.\ni like programmimg python.")

# %%
# WAF that replace all occurrences of “java” with “python” in above file

with open("practics.txt","r") as f:
     data =f.read()
new__data =data.replace(" java","python")
print(new__data)
# Out:
# hii everyone
#  we are learning file I/O
# using python.
# i like programmimg python.

# %%
# Search if the word “learning” exists in the file or not.
word = "learning "
with open("practics.txt", "r") as f:
     data = f.read()
     if(data.find(word) != -1 ):
          print("found")
     else:
          print("not found")
# Out:
# found

# %%
# same problem ,  solve  from functions 
def check_for_word():
     word = "learning "
with open("practics.txt", "r") as f:
     data = f.read()
     if(data.find(word) != -1 ):
          print("found")
     else:
          print("not found")
check_for_word()
# Out:
# found

# %%
# WAF to find in which line of the file does the word “learning”occur first. 
# Print -1 if word not found.
# 
def check_for_word():
     word = "learning "
with open("practics.txt", "r") as f:
     data = f.read()
     if(data.find(word) != -1 ):
          print("found")
     else:
          print("not found")
check_for_word()

def check_for_line():
     word = " like"
     data = True
     line_no= 1
     with open("practics.txt", "r") as f:
          while data :
               data = f.readline()
               if(word in data ):
                    print(line_no)
                    return
               line_no+= 1
     return -1
check_for_line()
# Out:
# found
# 4
