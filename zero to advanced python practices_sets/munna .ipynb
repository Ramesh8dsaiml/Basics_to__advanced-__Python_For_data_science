# %% [markdown]
# # print ("number converter ")
# int = int(input(" enter any number "))

# %%
# number converter 
print (" number converter ")
#
int = int(input(" enter any number "))


def main():

    
    list  = ('ten','twenty','thirty','fourty','fifty','Seventy ','ninety ')
    list  = ('zero','one','two','three ','four','five','six','seven', 'eight','nine')
    list  = ('twenty','thirty','forty','fifty','sixty','seventy','eighty','ninety')
    
    number = int  (input("enter the any number 0-1000: ")) # only 1000 range    
    print (int ("enter a range : n "))


    if number < 0 or number > 100:
        return "Out of range"

    if number == 100:
        return "one hundred"
    
    if number < 10:
        return units[number]
    
    elif number < 20:
        return teens[number - 10]
    
    else:
        print(q = number // 10)
        print(r = number % 10)
        
        tens_word = tens[q - 2]  
        
        if r == 0:
            return tens_word
        else:
            return f"{tens_word} {units[r]}"
        print()

        
        
         if number < 0 or number > 1000:
        return "Out of range"

    if number == 1000:
        return "one thousand"
    
    if number < 10:
        return units[number]
    
    elif number < 20:
        return teens[number - 10]
    
    else:

# %%
# number converter 
print (" number converter ")
#
int = int(input(" enter any number "))


def main():

    
    list  = ('ten','twenty','thirty','fourty','fifty','Seventy ','ninety ')
    list  = ('zero','one','two','three ','four','five','six','seven', 'eight','nine')
    list  = ('twenty','thirty','forty','fifty','sixty','seventy','eighty','ninety')
    list  = ('one thousand ',' two thousand ','three thousand ','four thousand ','five thousend ','six thousand ','seven thousand ','eight thousand ','nine thousand ')
    
    #number = int  (input("enter the any number 0-1000: ")) # only 1000 range    
    #print (int ("enter a range : n "))


    #if number < 0 or number > 100:
     #   return "Out of range"

    #if number == 100:
     #   return "one hundred"
    
    #if number < 10:
     #   return units[number]
    
    #elif number < 20:
     #   return teens[number - 10]
    
    #else:
     #   print(q = number // 10)
      #  print(r = number % 10)
        
       # tens_word = tens[q - 2]  
        
        #if r == 0:
         #   return tens_word
       # else:
         #   return f"{tens_word} {units[r]}"
       # print()

        
        
         if number < 0 or number > 100000:
        return "Out of range"

    if number == 10000r]
    
    elif number < 20:
        return teens[number - 10]
    
    else:
